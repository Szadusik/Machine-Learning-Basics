# %%
import PIL
from os import listdir
from os.path import isfile, join
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# %%
def get_all_images(filepath): #Function to get all .png files from directory consisting subset of dataset
    return [f for f in listdir(filepath) if isfile(join(filepath, f))]

# %%
def get_images(filepath):
    res = get_all_images(filepath)
    images = []
    for i in range(len(res)):
        im = PIL.Image.open(filepath + '/' + res[i])
        width, height = im.size
        im = im.crop((400,100,width,height))
        im = im.resize((150,150))
        im = ImageOps.grayscale(im)
        images.append(im)
    return images

# %%
autoRifles = get_images("ImageSets/AutoRifles")
pulseRifles = get_images("ImageSets/PulseRifles")
scoutRifles = get_images("ImageSets/ScoutRifles")

# %%
def save_observations(observations):   
    res = []
    for el in observations:
        im = np.array(el)
        size = np.shape(el)
        im = np.reshape(im,size[0]*size[1])
        res.append(im)
    return np.array(res)

observations = {
    'auto' : save_observations(autoRifles),
    'pulse': save_observations(pulseRifles),
    'scout': save_observations(scoutRifles)    
}

# %%
names = ['I','II','III','IV','V','VI','VII','VIII','IX','X','XI','XII','XIII','XIV','XV','XVI','XVII','XVIII','XIX','X']

for i in range (len(autoRifles)):
    autoRifles[i].save('ImageSets/AutoRiflesConverted/'+ names[i] + '.png')
    pulseRifles[i].save('ImageSets/PulseRiflesConverted/'+ names[i] + '.png')
    scoutRifles[i].save('ImageSets/ScoutRiflesConverted/'+ names[i] + '.png')

# %%
res = np.cov(observations['auto'].T) #Covariance matrices before using PCA
res2 = np.cov(observations['pulse'].T)
res3 = np.cov(observations['scout'].T)

# %%
# np.savetxt("CovarianceMatrices/auto.csv",np.float16(res),delimiter=";")
# np.savetxt("CovarianceMatrices/pulse.csv",np.float16(res2),delimiter=";")
# np.savetxt("CovarianceMatrices/scout.csv",np.float16(res2),delimiter=";")

# %% [markdown]
# # Wariancje

# %%
pca = PCA()

# %%
pca.fit(observations['auto'])
# Out:
# PCA()

# %%
resAfter = np.cov(pca.fit_transform(observations['auto']))

# %%
def plot_variance(covMatrix):
    n = np.shape(covMatrix)[0]
    X = []
    variance = []
    for i in range(n):
        X.append(i+1)
        variance.append(covMatrix[i][i])
    
    plt.rcParams["figure.figsize"] = (16,9)
    plt.scatter(X,variance, color='orange')
    plt.xlabel("Dana określona cecha")
    plt.ylabel("Wartość wariancji dla określonej cechy")

# %%
plt.title("Rozkład wariancji obliczone dla poszczegolnych cech (Karabiny automatyczne) - przed PCA")
plot_variance(res)

# %%
plt.title("Rozkład wariancji obliczone dla poszczegolnych cech (Karabiny automatyczne) - po PCA")
plot_variance(resAfter)

# %%
pca.fit(observations['pulse'])
res2After = np.cov(pca.fit_transform(observations['pulse']))

# %%
plt.title("Rozkład wariancji obliczone dla poszczegolnych cech (Karabiny pulsacyjne) - przed PCA")
plot_variance(res2)

# %%
plt.title("Rozkład wariancji obliczone dla poszczegolnych cech (Karabiny pulsacyjne) - po PCA")
plot_variance(res2After)

# %%
pca.fit(observations['scout'])
res3After = np.cov(pca.fit_transform(observations['scout']))

# %%
plt.title("Rozkład wariancji obliczone dla poszczegolnych cech (Karabiny zwiadowcze) - przed PCA")
plot_variance(res3)

# %%
plt.title("Rozkład wariancji obliczone dla poszczegolnych cech (Karabiny zwiadowcze) - po PCA")
plot_variance(res3After)

# %% [markdown]
# # Macierze kowariancji

# %%
# np.savetxt("CovarianceMatrices/autoAfter.csv",resAfter,delimiter=";")
# np.savetxt("CovarianceMatrices/pulseAfter.csv",res2After,delimiter=";")
# np.savetxt("CovarianceMatrices/scoutAfter.csv",res3After,delimiter=";")

# %%
sns.heatmap(resAfter).set(title='Macierz kowariancji po transformacji PCA (Karabiny Automatyczne)')
# Out:
# [Text(0.5, 1.0, 'Macierz kowariancji po transformacji PCA (Karabiny Automatyczne)')]

# %%
sns.heatmap(res2After).set(title='Macierz kowariancji po transformacji PCA (Karabiny Pulsacyjne)')
# Out:
# [Text(0.5, 1.0, 'Macierz kowariancji po transformacji PCA (Karabiny Pulsacyjne)')]

# %%
sns.heatmap(res3After).set(title='Macierz kowariancji po transformacji PCA (Karabiny Zwiadowcze)')
# Out:
# [Text(0.5, 1.0, 'Macierz kowariancji po transformacji PCA (Karabiny Zwiadowcze)')]

# %% [markdown]
# # Średnie zdjęcia

# %%
pca.fit(observations['auto'])
autoMean = pca.mean_

# %%
pca.fit(observations['pulse'])
pulseMean = pca.mean_

# %%
pca.fit(observations['scout'])
scouteMean = pca.mean_

# %%
autoMean = np.reshape(autoMean,(150,150))
pulseMean = np.reshape(pulseMean,(150,150))
scoutMean = np.reshape(scoutMean,(150,150))

# %%
autoim = Image.fromarray(autoMean).convert("L")
pulseim = Image.fromarray(pulseMean).convert("L")
scoutim = Image.fromarray(scoutMean).convert("L")

autoim.save('ImageSets/MeanImages/autoMean.png')
pulseim.save('ImageSets/MeanImages/pulseMean.png')
scoutim.save('ImageSets/MeanImages/scoutMean.png')

# %% [markdown]
# # Wektory bazowe

# %%
pca.fit(observations['auto'])
autoVectors = pca.components_

# %%
pca.fit(observations['pulse'])
pulseVectors = pca.components_

# %%
pca.fit(observations['scout'])
scoutVectors = pca.components_

# %%
def visualize_components(path,components):
    n = np.shape(components)[0]
    for i in range(n):
        vector = components[i]
        vector = np.reshape(vector,(150,150))
        im = Image.fromarray(vector).convert("L")
        im.save(path + str(i) + '.png')

# %%
visualize_components('ImageSets/AutoComponents/',autoVectors)
visualize_components('ImageSets/PulseComponents/',pulseVectors)
visualize_components('ImageSets/ScoutComponents/',scoutVectors)

# %% [markdown]
# # Redukcja wymiarów

# %%
def get_most_important_features(covariance,amount):
    n = np.shape(covariance)[0]
    variance = []
    features = []
    for i in range(n):
        variance.append((covariance[i][i],i))
    variance = sorted(variance,key=lambda p:p[0],reverse=True)
    for i in range(amount):
        features.append(variance[i][1])
        
    return features

def apply_zero_reduction(observations,features):
    n = np.shape(observations)
    for i in range(n[0]):
        for j in range(n[1]):
            if j not in features:
                observations[i][j] = 0
    return observations

def get_results(reducedset,components,meanVector):
    for i in range(np.shape(reducedset)[0]):
        reducedset[i] = np.dot(reducedset[i],components[i]) + meanVector
    return reducedset

# %%
featuresAmount = [3,9,27]
types = [('auto','AutoRifles'),('pulse','PulseRifles'),('scout','ScoutRifles')]
for t in types:
    pca.fit(observations[t[0]])
    for el in featuresAmount:
        reduced = np.copy(observations[t[0]])
        features = get_most_important_features(pca.get_covariance(),el)
        reduced = apply_zero_reduction(reduced,features)
        visualize_components('ImageSets/ReducedImages/' + t[1] + str(el) + '/',reduced)

# %% [markdown]
# # Mapowanie 2D

# %%
pca = PCA(n_components=2)

# %%
auto2D = pca.fit_transform(observations['auto'])
pulse2D = pca.fit_transform(observations['pulse'])
scout2D = pca.fit_transform(observations['scout'])

# %%
def convertIntoCoordinates(observations):
    X = []
    Y = []
    for i in range(np.shape(observations)[0]):
        X.append(observations[i][0])
        Y.append(observations[i][1])
    return X,Y

# %%
autoCords = convertIntoCoordinates(auto2D)
pulseCords = convertIntoCoordinates(pulse2D)
scoutCords = convertIntoCoordinates(scout2D)

# %%
plt.rcParams["figure.figsize"] = (16,9)
plt.xlabel("Pierwsza wybrana cecha danej obserwacji")
plt.ylabel("Druga wybrana cecha danej obserwacji")
plt.title("Zobrazowanie obserwacji na plaszczyznie 2D po zastosowaniu PCA")
plt.scatter(autoCords[0],autoCords[1],label = 'Auto rifle',marker = 'o', color='orange')
plt.scatter(pulseCords[0],pulseCords[1],label = 'Pulse rifle',marker = '*', color='red')
plt.scatter(scoutCords[0],scoutCords[1],label = 'Scout rifle',marker = '^', color='cyan')
plt.legend()
plt.show()
